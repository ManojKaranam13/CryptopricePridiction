# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, GRU
from sklearn.model_selection import train_test_split

# %%
# Load the data
file_path = 'BTC.csv'
data = pd.read_csv(file_path)

# Display the first few rows to understand the structure of the dataset
data.head(), data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5160 entries, 0 to 5159
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  5160 non-null   object
#  1   date    5160 non-null   object
#  2   open    5160 non-null   float64
#  3   high    5160 non-null   float64
#  4   low     5160 non-null   float64
#  5   close   5160 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 242.0+ KB
# (  ticker        date     open     high      low    close
#  0    BTC  2010-07-17  0.04951  0.04951  0.04951  0.04951
#  1    BTC  2010-07-18  0.04951  0.08585  0.04951  0.08584
#  2    BTC  2010-07-19  0.08584  0.09307  0.07723  0.08080
#  3    BTC  2010-07-20  0.08080  0.08181  0.07426  0.07474
#  4    BTC  2010-07-21  0.07474  0.07921  0.06634  0.07921,
#  None)

# %%
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# Select the necessary columns for modeling
prices = data[['open', 'high', 'low', 'close']].values

# %%
import matplotlib.pyplot as plt
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_prices = scaler.fit_transform(prices)

data['date'] = pd.to_datetime(data['date'])

data.set_index('date', inplace=True)

# Visualize the Open, High, Low, and Close prices over time
plt.figure(figsize=(14, 7))
plt.plot(data['close'], label='Close Price')
plt.plot(data['open'], label='Open Price', alpha=0.6)
plt.plot(data['high'], label='High Price', alpha=0.6)
plt.plot(data['low'], label='Low Price', alpha=0.6)
plt.title('Bitcoin Prices Over Time', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(data[i + sequence_length][-1])  # Predicting 'close' price
    return np.array(X), np.array(y)

sequence_length = 60
X, y = create_sequences(scaled_prices, sequence_length)

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
gru_model = Sequential()
gru_model.add(GRU(units=50, return_sequences=True))
gru_model.add(GRU(units=50))
gru_model.add(Dense(25))
gru_model.add(Dense(1))

gru_model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the GRU model
gru_model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - loss: 0.0114
# Epoch 2/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.4847e-04
# Epoch 3/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.3786e-04
# Epoch 4/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.2721e-04
# Epoch 5/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.1013e-04
# Epoch 6/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 9.1834e-05
# Epoch 7/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.0768e-04
# Epoch 8/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.1385e-04
# Epoch 9/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.3816e-04
# Epoch 10/10
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 9.3219e-05

# %%
gru_history = gru_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 2.5565e-05 - val_loss: 3.7243e-04
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1078e-05 - val_loss: 3.3365e-04
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.2028e-05 - val_loss: 3.1442e-04
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.2975e-05 - val_loss: 3.2079e-04
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.1116e-05 - val_loss: 3.1531e-04
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.0739e-05 - val_loss: 3.1324e-04
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.4882e-05 - val_loss: 3.2985e-04
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.1221e-05 - val_loss: 3.0610e-04
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.2274e-05 - val_loss: 3.2846e-04
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1700e-05 - val_loss: 3.2896e-04
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 1.1097e-05 - val_loss: 3.1085e-04
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.0427e-05 - val_loss: 3.1074e-04
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 8.8907e-06 - val_loss: 3.0455e-04
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 1.4191e-05 - val_loss: 3.0309e-04
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.2163e-05 - val_loss: 3.0081e-04
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1594e-05 - val_loss: 3.0021e-04
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.0150e-05 - val_loss: 2.9749e-04
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.2904e-05 - val_loss: 3.6668e-04
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.0011e-05 - val_loss: 2.9655e-04
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.0646e-05 - val_loss: 3.1364e-04
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.1545e-05 - val_loss: 2.9461e-04
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1463e-05 - val_loss: 2.9355e-04
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.3773e-05 - val_loss: 3.0209e-04
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 1.0347e-05 - val_loss: 2.9213e-04
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 9.9536e-06 - val_loss: 3.2419e-04
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 9.9902e-06 - val_loss: 3.0153e-04
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0687e-05 - val_loss: 2.9032e-04
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.1919e-05 - val_loss: 2.9827e-04
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 9.0116e-06 - val_loss: 2.9722e-04
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 1.1325e-05 - val_loss: 2.9133e-04
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.1365e-05 - val_loss: 2.8811e-04
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1302e-05 - val_loss: 2.9085e-04
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0923e-05 - val_loss: 2.8621e-04
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 9.2535e-06 - val_loss: 2.8506e-04
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 1.2121e-05 - val_loss: 2.8560e-04
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 1.1841e-05 - val_loss: 2.8586e-04
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 9.8630e-06 - val_loss: 2.9396e-04
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 1.0215e-05 - val_loss: 3.1213e-04
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 9.0851e-06 - val_loss: 3.1197e-04
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 9.2009e-06 - val_loss: 2.8435e-04
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 9.5210e-06 - val_loss: 2.9632e-04
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 1.0145e-05 - val_loss: 2.8207e-04
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.8057e-06 - val_loss: 2.8219e-04
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 1.0245e-05 - val_loss: 2.9868e-04
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 1.2459e-05 - val_loss: 2.8806e-04
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 9.3385e-06 - val_loss: 3.9182e-04
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 1.1119e-05 - val_loss: 2.7767e-04
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 8.0564e-06 - val_loss: 2.7788e-04
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 1.0346e-05 - val_loss: 2.7743e-04
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 1.2645e-05 - val_loss: 2.8597e-04

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(gru_history.history['loss'], label='Training Loss')
plt.plot(gru_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
gru_loss = gru_model.evaluate(X_test, y_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5953e-04

# %%
gru_predictions = gru_model.predict(X_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
cnn_predictions = scaler.inverse_transform(np.concatenate((np.zeros((gru_predictions.shape[0], 3)), gru_predictions), axis=1))[:, -1]
print(f'CNN Predictions: {cnn_predictions}')
# Out:
# CNN Predictions: [64301.17532139 60265.61653375 59217.17520233 ... 58527.35884925
#  59783.77526061 58733.48936085]
